# %% [markdown]
# S. AUREUS GSMM NDH-2 DELETIONS

# %%
from __future__ import print_function
import cobra
import os
from os.path import join
import pandas as pd
from cobra.medium import minimal_medium
from cobra import Model, Reaction, Metabolite
import copy
import numpy as np

# %%
data_dir = "C:/Users/Guillem/Documents/PhD/comput/models/SAureus"

# %%
# Load iSA863, iSB619 and iYS854 sbml models
iSA863 = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
# Out:
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite '2bdgsglyc_e' used in reaction '2BDabc'
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite '2obut_e' used in reaction '2OBUT_Et'
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite '3gmp_e' used in reaction '3GMPtex'
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite 'abt_e' used in reaction 'ABT_Et'
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite 'acgal_e' used in reaction 'ACGAL_Et'
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite 'acgam_e' used in reaction 'ACGApts'
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite 'acmana_e' used in reaction 'ACMANAtex'
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite 'ac_e' used in reaction 'ACTt2r'
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite 'ad_e' used in reaction 'AD_Et'
# cobra\io\sbml3.py:340 UserWarning: Boundary metabolite 'h_e' used in reaction 'ADNt2'
# ...

# %%
iSB619 = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))

# %%
iYS854 = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))

# %% [markdown]
# Examine each one of the loaded models

# %%
iSA863
# Out:
# <Model SAUSA300_FPR3757 at 0x1ebf2ae5a08>

# %%
iSB619
# Out:
# <Model iSB619 at 0x1eb962f3688>

# %%
iYS854
# Out:
# <Model iYS854 at 0x1eb98944c48>

# %%
iSA863.metabolites.get_by_id('dhor__S_c')
# Out:
# <Metabolite dhor__S_c at 0x1eb963dbb88>

# %%
iSA863.reactions.get_by_id('DHORD')
# Out:
# <Reaction DHORD at 0x1eb9677b488>

# %%
iSA863.reactions.get_by_id('DHORTS')
# Out:
# <Reaction DHORTS at 0x1eb96773408>

# %%
iSA863.reactions.get_by_id('DHORD5')
# Out:
# <Reaction DHORD5 at 0x1eb966c8e48>

# %% [markdown]
# FBA of each one of the unaltered models.

# %%
# shut down carbon sources from medium to force model to use glucose

#iSA863_medium = iSA863.medium
#iSA863_medium["EX_glyc3p_e"] = 0.0
#iSA863_medium["EX_man_e"] = 0.0
#iSA863_medium["EX_fru_e"] = 0.0 # Still flux
#iSA863_medium["EX_ac_e"] = 0.0 # Still flux
#iSA863_medium["EX_lac__L_e"] = 0.0 # Still flux
#iSA863_medium["EX_akg_e"] = 0.0 # Still flux
#iSA863_medium["EX_pyr_e"] = 0.0 # Still flux
#iSA863_medium["EX_arab__L_e"] = 0.0 # Still flux
#iSA863.medium = iSA863_medium
#iSA863_medium
#iSA863.medium

# %%
# Constrain EtOH exchange to make it to allow only secretion
#iSA863.reactions.EX_etoh_e.bounds = -1000.0, 0.0
#iSA863.reactions.EX_fru_e.bounds = -1000.0, 0.0
#iSA863.reactions.EX_ac_e.bounds = -1000.0, 0.0
#iSA863.reactions.EX_for_e.bounds = -1000.0, 0.0
#iSA863.reactions.EX_lac__L_e.bounds = -1000.0, 0.0
#iSA863.reactions.EX_akg_e.bounds = -1000.0, 0.0
#iSA863.reactions.EX_pyr_e.bounds = -1000.0, 0.0
#iSA863.reactions.EX_arab__L_e.bounds = -1000.0, 0.0

#print(iSA863.reactions.EX_etoh_e.bounds)
#print(iSA863.reactions.EX_fru_e.bounds)
#print(iSA863.reactions.EX_ac_e.bounds)
#print(iSA863.reactions.EX_for_e.bounds)
#print(iSA863.reactions.EX_lac__L_e.bounds)
#print(iSA863.reactions.EX_akg_e.bounds)
#print(iSA863.reactions.EX_pyr_e.bounds)
#print(iSA863.reactions.EX_arab__L_e.bounds)

# %% [markdown]
# <h1>iSA863</h1>

# %%
iSA863_sol = iSA863.optimize()
iSA863_sol
# Out:
# <Solution 16.493 at 0x24356001588>

# %%
iSA863_sol_fluxes = iSA863_sol.fluxes
pd.set_option('display.max_rows', iSA863_sol_fluxes.shape[0]+1)
print(iSA863_sol_fluxes)
# Out:
# 10M3HDAHL               0.000000e+00
# 10M3HDHL                0.000000e+00
# 10M3OACPO               0.000000e+00
# 10M3OUO                 0.000000e+00
# 10MDOD                  0.000000e+00
# 10MTDAO                 0.000000e+00
# 10MTU2A                 0.000000e+00
# 10MUAM                  0.000000e+00
# 11M3ODO                 0.000000e+00
# 11MDAMCA                0.000000e+00
# 11MHDOD                 0.000000e+00
# 11MTRDOC                0.000000e+00
# 12M3HTDH                0.000000e+00
# 12M3HTHL                0.000000e+00
# 12M3OXOT                0.000000e+00
# 12M3TDA                 0.000000e+00
# 12MEDAT                 0.000000e+00
# 12METRAT                0.000000e+00
# 12MTACPM                0.000000e+00
# 12MTT2E                 0.000000e+00
# 12TTACA                 0.000000e+00
# 13M3HTDAHL              0.000000e+00
# 13M3OTDAO               0.000000e+00
# 13MTDAM                 0.000000e+00
# 13MTDAT                 0.000000e+00
# ...

# %%
print('Acetoin exchange: ', iSA863_sol_fluxes.EX_actn__R_e)
print('Acetate exchange: ', iSA863_sol_fluxes.EX_ac_e)
print('Formate exchange: ', iSA863_sol_fluxes.EX_for_e)
print('Pyruate exchange: ', iSA863_sol_fluxes.EX_pyr_e)
print('Lactate exchange: ', iSA863_sol_fluxes.EX_lac__L_e)
print('Mannose exchange: ', iSA863_sol_fluxes.EX_man_e)
print('Fructose exchange: ', iSA863_sol_fluxes.EX_fru_e)
print('Ethanol exchange: ', iSA863_sol_fluxes.EX_etoh_e)
print('Glucose exchange: ', iSA863_sol_fluxes.EX_glc_e)
print('Glucose-6-P exchange: ', iSA863_sol_fluxes.EX_g6p_e)
print('Glycine exchange: ', iSA863_sol_fluxes.EX_gly_e)
print('Trehalose exchange: ', iSA863_sol_fluxes.EX_tre_e)
print('Aspartate exchange: ', iSA863_sol_fluxes.EX_asp__L_e)
print('Glyceraldehyde-3-p exchange: ', iSA863_sol_fluxes.EX_glyc3p_e)
print('2-Oxoglutarate-b exchange: ', iSA863_sol_fluxes.EX_akg_e)
print('Arabinose exchange: ', iSA863_sol_fluxes.EX_arab__L_e)
# Out:
# Acetoin exchange:  0.0
# Acetate exchange:  0.0
# Formate exchange:  0.0
# Pyruate exchange:  0.0
# Lactate exchange:  0.0
# Mannose exchange:  0.0
# Fructose exchange:  0.0
# Ethanol exchange:  0.0
# Glucose exchange:  0.0
# Glucose-6-P exchange:  0.0
# Glycine exchange:  0.0
# Trehalose exchange:  0.0
# Aspartate exchange:  0.0
# Glyceraldehyde-3-p exchange:  0.0
# 2-Oxoglutarate-b exchange:  0.0
# Arabinose exchange:  0.0

# %%
# Do copy of iSA863 to add nadph reaction
iSA863_wNdh_2b = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))

# %%
# Create NADPH + menaquinone reaction
NADPH10 = Reaction('NADPH10')
NADPH10.name = 'NADPH dehydrogenase (menaquinone-8 and 0 protons) '
NADPH10.add_metabolites({
    iSA863.metabolites.get_by_id("h_c"): -1.0,
    iSA863.metabolites.get_by_id("nadph_c"): -1.0,
    iSA863.metabolites.get_by_id("mqn8_c"): -1.0,
    iSA863.metabolites.get_by_id("nadp_c"): 1.0,
    iSA863.metabolites.get_by_id("mql8_c"): 1.0,
})

# %%
iSA863_wNdh_2b.add_reactions([NADPH10])
iSA863_wNdh_2b.reactions.NADPH10
# Out:
# <Reaction NADPH10 at 0x243520938c8>

# %%
iSA863_wNdh_2b_sol = iSA863_wNdh_2b.optimize()
iSA863_wNdh_2b_sol
# Out:
# <Solution 16.493 at 0x2435338a608>

# %%
iSA863_wNdh_2b_sol_fluxes = iSA863_wNdh_2b_sol.fluxes
pd.set_option('display.max_rows', iSA863_wNdh_2b_sol_fluxes.shape[0]+1)
iSA863_wNdh_2b_sol_fluxes_df = pd.DataFrame(iSA863_wNdh_2b_sol_fluxes)
iSA863_wNdh_2b_sol_fluxes_df
# Out:
#                             fluxes
# 10M3HDAHL             0.000000e+00
# 10M3HDHL              0.000000e+00
# 10M3OACPO             0.000000e+00
# 10M3OUO               0.000000e+00
# 10MDOD                0.000000e+00
# 10MTDAO               0.000000e+00
# 10MTU2A               0.000000e+00
# 10MUAM                0.000000e+00
# 11M3ODO               0.000000e+00
# 11MDAMCA              0.000000e+00
# 11MHDOD               0.000000e+00
# 11MTRDOC              0.000000e+00
# 12M3HTDH              0.000000e+00
# 12M3HTHL              0.000000e+00
# 12M3OXOT              0.000000e+00
# 12M3TDA               0.000000e+00
# 12MEDAT               0.000000e+00
# 12METRAT              0.000000e+00
# 12MTACPM              0.000000e+00
# 12MTT2E               0.000000e+00
# 12TTACA               0.000000e+00
# 13M3HTDAHL            0.000000e+00
# 13M3OTDAO             0.000000e+00
# 13MTDAM               0.000000e+00
# 13MTDAT               0.000000e+00
# 13MTTDAO              0.000000e+00
# ...

# %%
iSA863_wNdh_2b_Reacts_id = []
iSA863_wNdh_2b_Reacts_name = []
iSA863_wNdh_2b_Reacts_stoich = []


for r in iSA863_wNdh_2b_sol_fluxes_df.index:
    iSA863_wNdh_2b_Reacts_id.append(r)
    iSA863_wNdh_2b_Reacts_name.append(iSA863_wNdh_2b.reactions.get_by_id(r).name)
    iSA863_wNdh_2b_Reacts_stoich.append(iSA863_wNdh_2b.reactions.get_by_id(r).reaction)

iSA863_wNdh_2b_Reacts_fluxes = list(iSA863_wNdh_2b_sol_fluxes)
iSA863_Reacts_fluxes = list(iSA863_sol_fluxes)
iSA863_Reacts_fluxes.append(0.0)

# %%
# NADH reactions are menaquinone, FF_31 quinone
iSA863_NADH7_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
iSA863_NADH10_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
iSA863_FF_31_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
iSA863_NADH7_NADH10_FF_31_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))

# Set the bounds to 0.0 to stop flux
iSA863_NADH7_del.reactions.NADH7.bounds = 0.0, 0.0
iSA863_NADH10_del.reactions.NADH10.bounds = 0.0, 0.0
iSA863_FF_31_del.reactions.FF_31.bounds = 0.0, 0.0
iSA863_NADH7_NADH10_FF_31_del.reactions.NADH7.bounds = 0.0, 0.0
iSA863_NADH7_NADH10_FF_31_del.reactions.NADH10.bounds = 0.0, 0.0
iSA863_NADH7_NADH10_FF_31_del.reactions.FF_31.bounds = 0.0, 0.0

# %%
iSA863_NADH7_del_sol = iSA863_NADH7_del.optimize()
iSA863_NADH10_del_sol = iSA863_NADH10_del.optimize()
iSA863_FF_31_del_sol = iSA863_FF_31_del.optimize()
iSA863_NADH7_NADH10_FF_31_del_sol = iSA863_NADH7_NADH10_FF_31_del.optimize()

iSA863_NADH7_del_fluxes = list(iSA863_NADH7_del_sol.fluxes)
iSA863_NADH10_del_fluxes = list(iSA863_NADH10_del_sol.fluxes)
iSA863_FF_31_del_fluxes = list(iSA863_FF_31_del_sol.fluxes)
iSA863_NADH7_NADH10_FF_31_del_fluxes = list(iSA863_NADH7_NADH10_FF_31_del_sol.fluxes)

iSA863_NADH7_del_fluxes.append(0.0)
iSA863_NADH10_del_fluxes.append(0.0)
iSA863_FF_31_del_fluxes.append(0.0)
iSA863_NADH7_NADH10_FF_31_del_fluxes.append(0.0)

# %%
# Do copies of model with NADPH reaction added to do the deletions (load model and add the reaction). 
iSA863_wNdh_2b_NADH7_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
iSA863_wNdh_2b_NADH10_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
iSA863_wNdh_2b_FF_31_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
iSA863_wNdh_2b_NADH7_NADH10_FF_31_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
iSA863_wNdh_2b_NADPH10_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))

iSA863_wNdh_2b_NADH7_del.add_reactions([NADPH10])
iSA863_wNdh_2b_NADH10_del.add_reactions([NADPH10])
iSA863_wNdh_2b_FF_31_del.add_reactions([NADPH10])
iSA863_wNdh_2b_NADH7_NADH10_FF_31_del.add_reactions([NADPH10])
iSA863_wNdh_2b_NADPH10_del.add_reactions([NADPH10])
iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del.add_reactions([NADPH10])

# %%
# Set the bounds to 0.0 to stop flux
iSA863_wNdh_2b_NADH7_del.reactions.NADH7.bounds = 0.0, 0.0

iSA863_wNdh_2b_NADH10_del.reactions.NADH10.bounds = 0.0, 0.0

iSA863_wNdh_2b_FF_31_del.reactions.FF_31.bounds = 0.0, 0.0

iSA863_wNdh_2b_NADH7_NADH10_FF_31_del.reactions.NADH7.bounds = 0.0, 0.0
iSA863_wNdh_2b_NADH7_NADH10_FF_31_del.reactions.NADH10.bounds = 0.0, 0.0
iSA863_wNdh_2b_NADH7_NADH10_FF_31_del.reactions.FF_31.bounds = 0.0, 0.0

iSA863_wNdh_2b_NADPH10_del.reactions.NADPH10.bounds = 0.0, 0.0

iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del.reactions.NADH7.bounds = 0.0, 0.0
iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del.reactions.NADH10.bounds = 0.0, 0.0
iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del.reactions.FF_31.bounds = 0.0, 0.0
iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del.reactions.NADPH10.bounds = 0.0, 0.0

# %%
# Obtain FBA solutions 
iSA863_wNdh_2b_NADH7_del_sol = iSA863_wNdh_2b_NADH7_del.optimize()
iSA863_wNdh_2b_NADH10_del_sol = iSA863_wNdh_2b_NADH10_del.optimize()
iSA863_wNdh_2b_FF_31_del_sol = iSA863_wNdh_2b_FF_31_del.optimize()
iSA863_wNdh_2b_NADH7_NADH10_FF_31_del_sol = iSA863_wNdh_2b_NADH7_NADH10_FF_31_del.optimize()
iSA863_wNdh_2b_NADPH10_del_sol = iSA863_wNdh_2b_NADPH10_del.optimize()
iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del_sol = iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del.optimize()

iSA863_wNdh_2b_NADH7_del_fluxes = list(iSA863_wNdh_2b_NADH7_del_sol.fluxes)
iSA863_wNdh_2b_NADH10_del_fluxes = list(iSA863_wNdh_2b_NADH10_del_sol.fluxes)
iSA863_wNdh_2b_FF_31_del_fluxes = list(iSA863_wNdh_2b_FF_31_del_sol.fluxes)
iSA863_wNdh_2b_NADH7_NADH10_FF_31_del_fluxes = list(iSA863_wNdh_2b_NADH7_NADH10_FF_31_del_sol.fluxes)
iSA863_wNdh_2b_NADPH10_del_fluxes = list(iSA863_wNdh_2b_NADPH10_del_sol.fluxes)
iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del_fluxes = list(iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del_sol.fluxes)

# %%
# Create dataframe with flux distributions with and without mutations
iSA863allDels = pd.DataFrame({'id':iSA863_wNdh_2b_Reacts_id, 'name':iSA863_wNdh_2b_Reacts_name, 'stoichiometry':iSA863_wNdh_2b_Reacts_stoich, 'iSA863_original_fluxes':iSA863_Reacts_fluxes, 'iSA863_with_ndh_2b_fluxes':iSA863_wNdh_2b_Reacts_fluxes, 'iSA863_NADH7_del_fluxes':iSA863_NADH7_del_fluxes, 'iSA863_NADH10_del_fluxes':iSA863_NADH10_del_fluxes, 'iSA863_FF_31_del_fluxes':iSA863_FF_31_del_fluxes,'iSA863_NADH7_NADH10_FF_31_del_fluxes':iSA863_NADH7_NADH10_FF_31_del_fluxes, 'iSA863_wNdh_2b_NADH7_del_fluxes':iSA863_wNdh_2b_NADH7_del_fluxes, 'iSA863_wNdh_2b_NADH10_del_fluxes':iSA863_wNdh_2b_NADH10_del_fluxes, 'iSA863_wNdh_2b_FF_31_del_fluxes':iSA863_wNdh_2b_FF_31_del_fluxes, 'iSA863_wNdh_2b_NADH7_NADH10_FF_31_del_fluxes':iSA863_wNdh_2b_NADH7_NADH10_FF_31_del_fluxes, 'iSA863_wNdh_2b_NADPH10_del_fluxes':iSA863_wNdh_2b_NADPH10_del_fluxes, 'iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del_fluxes':iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del_fluxes})

# %%
# Filter the dataframe to keep just fluxes that are altered between conditions
iSA863allDels_filt = iSA863allDels[iSA863allDels[['iSA863_original_fluxes', 'iSA863_with_ndh_2b_fluxes', 'iSA863_NADH7_del_fluxes', 'iSA863_NADH10_del_fluxes', 'iSA863_FF_31_del_fluxes', 'iSA863_NADH7_NADH10_FF_31_del_fluxes', 'iSA863_wNdh_2b_NADH7_del_fluxes', 'iSA863_wNdh_2b_NADH10_del_fluxes', 'iSA863_wNdh_2b_FF_31_del_fluxes', 'iSA863_wNdh_2b_NADH7_NADH10_FF_31_del_fluxes', 'iSA863_wNdh_2b_NADPH10_del_fluxes', 'iSA863_wNdh_2b_NADH7_NADH10_FF_31_NADPH_del_fluxes']].nunique(axis = 1).gt(1)]
iSA863allDels_filt
# Out:
#                         id                                               name  \
# 50                2OBUT_Et                           2-oxobutanoate transport
# 66              3M2OBLOXRD  3-Methyl-2-oxobutanoate:lipoamide oxidoreducta...
# 67              3M2OPLOXRD  3-Methyl-2-oxopentanoate:lipoamide oxidoreduct...
# 89              4M2OPLOXRD  4-Methyl-2-oxopentanoate:lipoamide oxidoreduct...
# 114                6PGALSZ                       6-phospho-beta-galactosidase
# 133                  AABTN                    4-acetamidobutyrate deacetylase
# 136                 ABT_Et                            L-Arabinitol transport
# 137                   ABTA                       4-aminobutyrate transaminase
# 141                ACACT1r                     acetyl-CoA C-acetyltransferase
# 146                  ACALD           acetaldehyde dehydrogenase (acetylating)
# 150                ACGApts  N-Acetyl__D-glucosamine transport via PEP:Pyr PTS
# ...

# %%
# Export csv file
iSA863allDels_filt.to_csv(path_or_buf='C:/Users/Guillem/Documents/PhD/comput/wrkng_dirs_clean/SAureus_simulations/iSA863allDels_filt.csv')

# %% [markdown]
# <h1>iSB619</h1>

# %%
iSB619_sol = iSB619.optimize()
iSB619_sol
# Out:
# <Solution 0.158 at 0x24350dd3fc8>

# %%
iSB619_sol_fluxes = iSB619_sol.fluxes
pd.set_option('display.max_rows', iSB619_sol_fluxes.shape[0]+1)
print(iSB619_sol_fluxes)
# Out:
# ADMDC                     1.580503e-03
# CO2t                     -2.390524e+03
# CSNt2                     1.205924e+00
# CYSabc                    0.000000e+00
# DAPE                      2.046751e+00
# DKMPPD                    0.000000e+00
# DKMPPD2                   1.580503e-03
# D_LACt2                   0.000000e+00
# 6PGALSZ                   0.000000e+00
# 6PHBG                     0.000000e+00
# ETOHt                     0.000000e+00
# EX_26dap__M_e             0.000000e+00
# ABTA                      0.000000e+00
# EX_Cit_Mg_e               0.000000e+00
# CHOLD                     0.000000e+00
# ACACT1r                   4.741509e-03
# ACACT2r                   0.000000e+00
# DDPA                      1.095289e+00
# ACALD                     0.000000e+00
# CHORM                     8.898231e-01
# ACOATA                    0.000000e+00
# ADNt2                     0.000000e+00
# ACLDC                     0.000000e+00
# ACNAMt2                   0.000000e+00
# ...

# %%
# print('Acetoin exchange: ', iSB619_sol_fluxes.EX_actn__R_e) --> Not present in the model
# print('Acetate exchange: ', iSB619_sol_fluxes.EX_ac_e) --> Not present in the model
print('Formate exchange: ', iSB619_sol_fluxes.EX_for_e)
# print('Pyruate exchange: ', iSB619_sol_fluxes.EX_pyr_e) --> Not present in the model
print('Lactate exchange: ', iSB619_sol_fluxes.EX_lac__D_e)
print('Ethanol exchange: ', iSB619_sol_fluxes.EX_etoh_e)
print('Glucose exchange: ', iSB619_sol_fluxes.EX_glc__D_e)
print('Glycine exchange: ', iSB619_sol_fluxes.EX_gly_e)
print('Trehalose exchange: ', iSB619_sol_fluxes.EX_tre_e)
print('Aspartate exchange: ', iSB619_sol_fluxes.EX_asp__L_e)
# Out:
# Formate exchange:  0.011063520412039595
# Lactate exchange:  0.0
# Ethanol exchange:  0.0
# Glucose exchange:  -980.7352414900927
# Glycine exchange:  0.0
# Trehalose exchange:  0.0
# Aspartate exchange:  0.0

# %%
# Do copy of iSB619 to add nadph reaction
iSB619_wNdh_2b = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))

# %%
iSB619_wNdh_2b.add_reactions([NADPH10])
iSB619_wNdh_2b.reactions.NADPH10
# Out:
# <Reaction NADPH10 at 0x243520938c8>

# %%
iSB619_wNdh_2b_sol = iSB619_wNdh_2b.optimize()
iSB619_wNdh_2b_sol
# Out:
# <Solution 0.158 at 0x2435f379c88>

# %%
iSB619_wNdh_2b_sol_fluxes = iSB619_wNdh_2b_sol.fluxes
pd.set_option('display.max_rows', iSB619_wNdh_2b_sol_fluxes.shape[0]+1)
iSB619_wNdh_2b_sol_fluxes_df = pd.DataFrame(iSB619_wNdh_2b_sol_fluxes)
iSB619_wNdh_2b_sol_fluxes_df
# Out:
#                               fluxes
# ADMDC                   1.580503e-03
# CO2t                   -2.390524e+03
# CSNt2                   1.205924e+00
# CYSabc                  0.000000e+00
# DAPE                    2.046751e+00
# DKMPPD                  0.000000e+00
# DKMPPD2                 1.580503e-03
# D_LACt2                 0.000000e+00
# 6PGALSZ                 0.000000e+00
# 6PHBG                   0.000000e+00
# ETOHt                   0.000000e+00
# EX_26dap__M_e           0.000000e+00
# ABTA                    0.000000e+00
# EX_Cit_Mg_e             0.000000e+00
# CHOLD                   0.000000e+00
# ACACT1r                 4.741509e-03
# ACACT2r                 0.000000e+00
# DDPA                    1.095289e+00
# ACALD                   0.000000e+00
# CHORM                   8.898231e-01
# ACOATA                  0.000000e+00
# ADNt2                   0.000000e+00
# ACLDC                   0.000000e+00
# ACNAMt2                 0.000000e+00
# ...

# %%
iSB619_wNdh_2b_Reacts_id = []
iSB619_wNdh_2b_Reacts_name = []
iSB619_wNdh_2b_Reacts_stoich = []


for r in iSB619_wNdh_2b_sol_fluxes_df.index:
    iSB619_wNdh_2b_Reacts_id.append(r)
    iSB619_wNdh_2b_Reacts_name.append(iSB619_wNdh_2b.reactions.get_by_id(r).name)
    iSB619_wNdh_2b_Reacts_stoich.append(iSB619_wNdh_2b.reactions.get_by_id(r).reaction)

iSB619_wNdh_2b_Reacts_fluxes = list(iSB619_wNdh_2b_sol_fluxes)
iSB619_Reacts_fluxes = list(iSB619_sol_fluxes)
iSB619_Reacts_fluxes.append(0.0)

# %%
# NADH reactions are menaquinone,
iSB619_NADH5_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_NADH6_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_NADH7_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_NADH8_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_NADH9_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_NADH10_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_NADH5_2_NADH10_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))

# Set the bounds to 0.0 to stop flux
iSB619_NADH5_del.reactions.NADH5.bounds = 0.0, 0.0
iSB619_NADH6_del.reactions.NADH6.bounds = 0.0, 0.0
iSB619_NADH7_del.reactions.NADH7.bounds = 0.0, 0.0
iSB619_NADH8_del.reactions.NADH8.bounds = 0.0, 0.0
iSB619_NADH9_del.reactions.NADH9.bounds = 0.0, 0.0
iSB619_NADH10_del.reactions.NADH10.bounds = 0.0, 0.0

iSB619_NADH5_2_NADH10_del.reactions.NADH5.bounds = 0.0, 0.0
iSB619_NADH5_2_NADH10_del.reactions.NADH6.bounds = 0.0, 0.0
iSB619_NADH5_2_NADH10_del.reactions.NADH7.bounds = 0.0, 0.0
iSB619_NADH5_2_NADH10_del.reactions.NADH8.bounds = 0.0, 0.0
iSB619_NADH5_2_NADH10_del.reactions.NADH9.bounds = 0.0, 0.0
iSB619_NADH5_2_NADH10_del.reactions.NADH10.bounds = 0.0, 0.0

# %%
iSB619_NADH5_del_sol = iSB619_NADH5_del.optimize()
iSB619_NADH6_del_sol = iSB619_NADH6_del.optimize()
iSB619_NADH7_del_sol = iSB619_NADH7_del.optimize()
iSB619_NADH8_del_sol = iSB619_NADH8_del.optimize()
iSB619_NADH9_del_sol = iSB619_NADH9_del.optimize()
iSB619_NADH10_del_sol = iSB619_NADH10_del.optimize()
iSB619_NADH5_2_NADH10_del_sol = iSB619_NADH5_2_NADH10_del.optimize()

iSB619_NADH5_del_fluxes = list(iSB619_NADH5_del_sol.fluxes)
iSB619_NADH6_del_fluxes = list(iSB619_NADH6_del_sol.fluxes)
iSB619_NADH7_del_fluxes = list(iSB619_NADH7_del_sol.fluxes)
iSB619_NADH8_del_fluxes = list(iSB619_NADH8_del_sol.fluxes)
iSB619_NADH9_del_fluxes = list(iSB619_NADH9_del_sol.fluxes)
iSB619_NADH10_del_fluxes = list(iSB619_NADH10_del_sol.fluxes)
iSB619_NADH5_2_NADH10_del_fluxes = list(iSB619_NADH5_2_NADH10_del_sol.fluxes)

iSB619_NADH5_del_fluxes.append(0.0)
iSB619_NADH6_del_fluxes.append(0.0)
iSB619_NADH7_del_fluxes.append(0.0)
iSB619_NADH8_del_fluxes.append(0.0)
iSB619_NADH9_del_fluxes.append(0.0)
iSB619_NADH10_del_fluxes.append(0.0)
iSB619_NADH5_2_NADH10_del_fluxes.append(0.0)

# %%
# Do copies of model with NADPH reaction added to do the deletions (load model and add the reaction). 
iSB619_wNdh_2b_NADH5_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_wNdh_2b_NADH6_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_wNdh_2b_NADH7_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_wNdh_2b_NADH8_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_wNdh_2b_NADH9_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_wNdh_2b_NADH10_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_wNdh_2b_NADH5_2_NADH10_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_wNdh_2b_NADPH10_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del = cobra.io.read_sbml_model(join(data_dir, "iSB619.xml"))

iSB619_wNdh_2b_NADH5_del.add_reactions([NADPH10])
iSB619_wNdh_2b_NADH6_del.add_reactions([NADPH10])
iSB619_wNdh_2b_NADH7_del.add_reactions([NADPH10])
iSB619_wNdh_2b_NADH8_del.add_reactions([NADPH10])
iSB619_wNdh_2b_NADH9_del.add_reactions([NADPH10])
iSB619_wNdh_2b_NADH10_del.add_reactions([NADPH10])
iSB619_wNdh_2b_NADH5_2_NADH10_del.add_reactions([NADPH10])
iSB619_wNdh_2b_NADPH10_del.add_reactions([NADPH10])
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del.add_reactions([NADPH10])

# %%
# Set the bounds to 0.0 to stop flux
iSB619_wNdh_2b_NADH5_del.reactions.NADH5.bounds = 0.0, 0.0

iSB619_wNdh_2b_NADH6_del.reactions.NADH6.bounds = 0.0, 0.0

iSB619_wNdh_2b_NADH7_del.reactions.NADH7.bounds = 0.0, 0.0

iSB619_wNdh_2b_NADH8_del.reactions.NADH8.bounds = 0.0, 0.0

iSB619_wNdh_2b_NADH9_del.reactions.NADH9.bounds = 0.0, 0.0

iSB619_wNdh_2b_NADH10_del.reactions.NADH10.bounds = 0.0, 0.0

iSB619_wNdh_2b_NADH5_2_NADH10_del.reactions.NADH5.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_del.reactions.NADH6.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_del.reactions.NADH7.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_del.reactions.NADH8.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_del.reactions.NADH9.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_del.reactions.NADH10.bounds = 0.0, 0.0

iSB619_wNdh_2b_NADPH10_del.reactions.NADPH10.bounds = 0.0, 0.0

iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del.reactions.NADH5.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del.reactions.NADH6.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del.reactions.NADH7.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del.reactions.NADH8.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del.reactions.NADH9.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del.reactions.NADH10.bounds = 0.0, 0.0
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del.reactions.NADPH10.bounds = 0.0, 0.0

# %%
# Obtain FBA solutions 
iSB619_wNdh_2b_NADH5_del_sol = iSB619_wNdh_2b_NADH5_del.optimize()
iSB619_wNdh_2b_NADH6_del_sol = iSB619_wNdh_2b_NADH6_del.optimize()
iSB619_wNdh_2b_NADH7_del_sol = iSB619_wNdh_2b_NADH7_del.optimize()
iSB619_wNdh_2b_NADH8_del_sol = iSB619_wNdh_2b_NADH8_del.optimize()
iSB619_wNdh_2b_NADH9_del_sol = iSB619_wNdh_2b_NADH9_del.optimize()
iSB619_wNdh_2b_NADH10_del_sol = iSB619_wNdh_2b_NADH10_del.optimize()
iSB619_wNdh_2b_NADH5_2_NADH10_del_sol = iSB619_wNdh_2b_NADH5_2_NADH10_del.optimize()
iSB619_wNdh_2b_NADPH10_del_sol = iSB619_wNdh_2b_NADPH10_del.optimize()
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del_sol = iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del.optimize()

iSB619_wNdh_2b_NADH5_del_fluxes = list(iSB619_wNdh_2b_NADH5_del_sol.fluxes)
iSB619_wNdh_2b_NADH6_del_fluxes = list(iSB619_wNdh_2b_NADH6_del_sol.fluxes)
iSB619_wNdh_2b_NADH7_del_fluxes = list(iSB619_wNdh_2b_NADH7_del_sol.fluxes)
iSB619_wNdh_2b_NADH8_del_fluxes = list(iSB619_wNdh_2b_NADH8_del_sol.fluxes)
iSB619_wNdh_2b_NADH9_del_fluxes = list(iSB619_wNdh_2b_NADH9_del_sol.fluxes)
iSB619_wNdh_2b_NADH10_del_fluxes = list(iSB619_wNdh_2b_NADH10_del_sol.fluxes)
iSB619_wNdh_2b_NADH5_2_NADH10_del_fluxes = list(iSB619_wNdh_2b_NADH5_2_NADH10_del_sol.fluxes)
iSB619_wNdh_2b_NADPH10_del_fluxes = list(iSB619_wNdh_2b_NADPH10_del_sol.fluxes)
iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del_fluxes = list(iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del_sol.fluxes)

# %%
# Create dataframe with flux distributions with and without mutations
iSB619allDels = pd.DataFrame({'id':iSB619_wNdh_2b_Reacts_id, 'name':iSB619_wNdh_2b_Reacts_name, 'stoichiometry':iSB619_wNdh_2b_Reacts_stoich, 'iSB619_original_fluxes':iSB619_Reacts_fluxes, 'iSB619_with_ndh_2b_fluxes':iSB619_wNdh_2b_Reacts_fluxes, 'iSB619_NADH5_del_fluxes':iSB619_NADH5_del_fluxes, 'iSB619_NADH6_del_fluxes':iSB619_NADH6_del_fluxes, 'iSB619_NADH7_del_fluxes':iSB619_NADH7_del_fluxes, 'iSB619_NADH8_del_fluxes':iSB619_NADH8_del_fluxes, 'iSB619_NADH9_del_fluxes':iSB619_NADH9_del_fluxes, 'iSB619_NADH10_del_fluxes':iSB619_NADH10_del_fluxes, 'iSB619_NADH5_2_NADH10_del_fluxes':iSB619_NADH5_2_NADH10_del_fluxes, 'iSB619_wNdh_2b_NADH5_del_fluxes':iSB619_wNdh_2b_NADH5_del_fluxes, 'iSB619_wNdh_2b_NADH6_del_fluxes':iSB619_wNdh_2b_NADH6_del_fluxes, 'iSB619_wNdh_2b_NADH7_del_fluxes':iSB619_wNdh_2b_NADH7_del_fluxes, 'iSB619_wNdh_2b_NADH8_del_fluxes':iSB619_wNdh_2b_NADH8_del_fluxes, 'iSB619_wNdh_2b_NADH9_del_fluxes':iSB619_wNdh_2b_NADH9_del_fluxes, 'iSB619_wNdh_2b_NADH10_del_fluxes':iSB619_wNdh_2b_NADH10_del_fluxes, 'iSB619_wNdh_2b_NADH5_2_NADH10_del_fluxes':iSB619_wNdh_2b_NADH5_2_NADH10_del_fluxes, 'iSB619_wNdh_2b_NADPH10_del_fluxes':iSB619_wNdh_2b_NADPH10_del_fluxes, 'iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del_fluxes':iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del_fluxes})

# %%
# Filter the dataframe to keep just fluxes that are altered between conditions
iSB619allDels_filt = iSB619allDels[iSB619allDels[['iSB619_original_fluxes', 'iSB619_with_ndh_2b_fluxes', 'iSB619_NADH5_del_fluxes', 'iSB619_NADH6_del_fluxes', 'iSB619_NADH7_del_fluxes', 'iSB619_NADH8_del_fluxes', 'iSB619_NADH9_del_fluxes', 'iSB619_NADH10_del_fluxes', 'iSB619_NADH5_2_NADH10_del_fluxes', 'iSB619_wNdh_2b_NADH5_del_fluxes', 'iSB619_wNdh_2b_NADH6_del_fluxes', 'iSB619_wNdh_2b_NADH7_del_fluxes', 'iSB619_wNdh_2b_NADH8_del_fluxes', 'iSB619_wNdh_2b_NADH9_del_fluxes', 'iSB619_wNdh_2b_NADH10_del_fluxes',  'iSB619_wNdh_2b_NADH5_2_NADH10_del_fluxes', 'iSB619_wNdh_2b_NADPH10_del_fluxes', 'iSB619_wNdh_2b_NADH5_2_NADH10_NADPH10_del_fluxes']].nunique(axis = 1).gt(1)]
iSB619allDels_filt
# Out:
#                     id                                               name  \
# 0                ADMDC                   Adenosylmethionine decarboxylase
# 1                 CO2t                      CO2 transporter via diffusion
# 2                CSNt2           Cytosine transport in via proton symport
# 4                 DAPE                          Diaminopimelate epimerase
# 5               DKMPPD  2,3-diketo-5-methylthio-1-phosphopentane degra...
# 6              DKMPPD2  2 3 diketo 5 methylthio 1 phosphopentane degra...
# 15             ACACT1r                     Acetyl-CoA C-acetyltransferase
# 16             ACACT2r    Acetyl-CoA C-acyltransferase (butanoyl-CoA) (r)
# 17                DDPA  3-deoxy-D-arabino-heptulosonate 7-phosphate sy...
# 19               CHORM                                  Chorismate mutase
# 24               CHORS                                Chorismate synthase
# 25              ACCOAC                             Acetyl-CoA carboxylase
# ...

# %%
# Export csv file
iSB619allDels_filt.to_csv(path_or_buf='C:/Users/Guillem/Documents/PhD/comput/wrkng_dirs_clean/SAureus_simulations/iSB619allDels_filt.csv')

# %% [markdown]
# <h1>iYS854</h1>

# %%
# Determine minimal medium to see what is the preferred carbon source. 

max_growth = iYS854.slim_optimize()
minimal_medium(iYS854, max_growth)
# Out:
# EX_h_e         10.000000
# EX_k_e          0.252580
# EX_cl_e         0.006736
# EX_cys__L_e     0.245264
# EX_mg2_e        0.011226
# EX_mn2_e        0.000895
# EX_mobd_e       0.000010
# EX_na1_e        2.706168
# EX_fe2_e        0.009970
# EX_fe3_e        0.010104
# EX_nac_e        0.000115
# EX_nh4_e       10.000000
# EX_o2_e        14.083687
# EX_glc__D_e    10.000000
# EX_so4_e        0.005612
# EX_thm_e        0.000607
# EX_zn2_e        0.000441
# dtype: float64

# %%
# the model prefers using as carbon source glyceraldehyde 3 phosphate, so let's shut exchange down to make it use glucose

iYS854_medium = iYS854.medium
iYS854_medium["EX_glyc3p_e"] = 0.0
iYS854.medium = iSA863_medium
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-18f503ef4009> in <module>
#       3 iYS854_medium = iYS854.medium
#       4 iYS854_medium["EX_glyc3p_e"] = 0.0
# ----> 5 iYS854.medium = iSA863_medium
#
# NameError: name 'iSA863_medium' is not defined

# %%
iYS854_sol = iYS854.optimize()
iYS854_sol
# Out:
# <Solution 1.360 at 0x24363af8448>

# %%
iYS854_sol_fluxes = iYS854_sol.fluxes
pd.set_option('display.max_rows', iYS854_sol_fluxes.shape[0]+1)
print(iYS854_sol_fluxes)

print('Acetoin exchange: ', iYS854_sol_fluxes.EX_actn__R_e)
print('Acetate exchange: ', iYS854_sol_fluxes.EX_ac_e)
print('Formate exchange: ', iYS854_sol_fluxes.EX_for_e)
print('Pyruate exchange: ', iYS854_sol_fluxes.EX_pyr_e)
print('Lactate exchange: ', iYS854_sol_fluxes.EX_lac__D_e)
print('Ethanol exchange: ', iYS854_sol_fluxes.EX_etoh_e)
print('Glucose exchange: ', iYS854_sol_fluxes.EX_glc__D_e)
print('Glycine exchange: ', iYS854_sol_fluxes.EX_gly_e)
print('Trehalose exchange: ', iYS854_sol_fluxes.EX_tre_e)
print('Aspartate exchange: ', iYS854_sol_fluxes.EX_asp__L_e)
# Out:
# 10M3HDHL                          4.123650e-03
# 10M3OACPO                         7.868403e-02
# 10M3OUO                           4.123650e-03
# 10MDOD                            7.868403e-02
# 10MTDAO                           7.868403e-02
# 10MTU2A                           4.123650e-03
# 10MUAM                            4.123650e-03
# 11M3ODO                           2.431161e-02
# 11MDAMCA                          2.431161e-02
# 11MHDOD                           2.431161e-02
# 11MTRDOC                          2.431161e-02
# 12M3HTDH                          7.868403e-02
# 12M3HTHL                          4.123650e-03
# 12M3OXOT                          4.123650e-03
# 12M3TDA                           7.868403e-02
# 12MTACPM                          3.334778e-03
# 12MTT2E                           4.123650e-03
# 12TTACA                           7.868403e-02
# ACALD                             0.000000e+00
# 3OAS120_2                         1.102031e-02
# ...

# %%
# Do copy of iSB619 to add nadph reaction
iYS854_wNdh_2b = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))

# %%
# Create NADPH + menaquinone reaction: in the iYS854 model menaquinone is encoded differently
NADPH4 = Reaction('NADPH4')
NADPH4.name = 'NADPH dehydrogenase (menaquinone-7 and 0 protons) '
NADPH4.add_metabolites({
    iYS854.metabolites.get_by_id("h_c"): -1.0,
    iYS854.metabolites.get_by_id("nadph_c"): -1.0,
    iYS854.metabolites.get_by_id("mqn7_c"): -1.0,
    iYS854.metabolites.get_by_id("nadp_c"): 1.0,
    iYS854.metabolites.get_by_id("mql7_c"): 1.0,
})

# %%
iYS854_wNdh_2b.add_reactions([NADPH4])
iYS854_wNdh_2b.reactions.NADPH4
# Out:
# <Reaction NADPH4 at 0x2436b3e8188>

# %%
iYS854_wNdh_2b_sol = iYS854_wNdh_2b.optimize()
iYS854_wNdh_2b_sol
# Out:
# <Solution 1.360 at 0x2436b3ce808>

# %%
iYS854_wNdh_2b_sol_fluxes = iYS854_wNdh_2b_sol.fluxes
pd.set_option('display.max_rows', iYS854_wNdh_2b_sol_fluxes.shape[0]+1)
iYS854_wNdh_2b_sol_fluxes_df = pd.DataFrame(iYS854_wNdh_2b_sol_fluxes)
iYS854_wNdh_2b_sol_fluxes_df
# Out:
#                                    fluxes
# 10M3HDHL                         0.004124
# 10M3OACPO                        0.078684
# 10M3OUO                          0.004124
# 10MDOD                           0.078684
# 10MTDAO                          0.078684
# 10MTU2A                          0.004124
# 10MUAM                           0.004124
# 11M3ODO                          0.024312
# 11MDAMCA                         0.024312
# 11MHDOD                          0.024312
# 11MTRDOC                         0.024312
# 12M3HTDH                         0.078684
# 12M3HTHL                         0.004124
# 12M3OXOT                         0.004124
# 12M3TDA                          0.078684
# 12MTACPM                         0.003335
# 12MTT2E                          0.004124
# 12TTACA                          0.078684
# ACALD                            0.000000
# 3OAS120_2                        0.011020
# 13M3HTDAHL                       0.024312
# ...

# %%
iYS854_wNdh_2b_Reacts_id = []
iYS854_wNdh_2b_Reacts_name = []
iYS854_wNdh_2b_Reacts_stoich = []


for r in iYS854_wNdh_2b_sol_fluxes_df.index:
    iYS854_wNdh_2b_Reacts_id.append(r)
    iYS854_wNdh_2b_Reacts_name.append(iYS854_wNdh_2b.reactions.get_by_id(r).name)
    iYS854_wNdh_2b_Reacts_stoich.append(iYS854_wNdh_2b.reactions.get_by_id(r).reaction)

iYS854_wNdh_2b_Reacts_fluxes = list(iYS854_wNdh_2b_sol_fluxes)
iYS854_Reacts_fluxes = list(iYS854_sol_fluxes)
iYS854_Reacts_fluxes.append(0.0)

# %%
# NADH reactions are menaquinone,
iYS854_NADH4_del = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))
iYS854_FADH2D_del = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))
iYS854_NADH4_FADH2D_del = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))

# Set the bounds to 0.0 to stop flux
iYS854_NADH4_del.reactions.NADH4.bounds = 0.0, 0.0
iYS854_FADH2D_del.reactions.FADH2D.bounds = 0.0, 0.0

iYS854_NADH4_FADH2D_del.reactions.NADH4.bounds = 0.0, 0.0
iYS854_NADH4_FADH2D_del.reactions.FADH2D.bounds = 0.0, 0.0

# %%
iYS854_NADH4_del_sol = iYS854_NADH4_del.optimize()
iYS854_FADH2D_del_sol = iYS854_FADH2D_del.optimize()
iYS854_NADH4_FADH2D_del_sol = iYS854_NADH4_FADH2D_del.optimize()

iYS854_NADH4_del_fluxes = list(iYS854_NADH4_del_sol.fluxes)
iYS854_FADH2D_del_fluxes = list(iYS854_FADH2D_del_sol.fluxes)
iYS854_NADH4_FADH2D_del_fluxes = list(iYS854_NADH4_FADH2D_del_sol.fluxes)

iYS854_NADH4_del_fluxes.append(0.0)
iYS854_FADH2D_del_fluxes.append(0.0)
iYS854_NADH4_FADH2D_del_fluxes.append(0.0)

# %%
# Do copies of model with NADPH reaction added to do the deletions (load model and add the reaction). 
iYS854_wNdh_2b_NADH4_del = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))
iYS854_wNdh_2b_FADH2D_del = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))
iYS854_wNdh_2b_NADH4_FADH2D_del = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))
iYS854_wNdh_2b_NADPH4_del = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))
iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del = cobra.io.read_sbml_model(join(data_dir, "iYS854.xml"))

iYS854_wNdh_2b_NADH4_del.add_reactions([NADPH4])
iYS854_wNdh_2b_FADH2D_del.add_reactions([NADPH4])
iYS854_wNdh_2b_NADH4_FADH2D_del.add_reactions([NADPH4])
iYS854_wNdh_2b_NADPH4_del.add_reactions([NADPH4])
iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del.add_reactions([NADPH4])

# %%
# Set the bounds to 0.0 to stop flux
iYS854_wNdh_2b_NADH4_del.reactions.NADH4.bounds = 0.0, 0.0

iYS854_wNdh_2b_FADH2D_del.reactions.FADH2D.bounds = 0.0, 0.0

iYS854_wNdh_2b_NADH4_FADH2D_del.reactions.NADH4.bounds = 0.0, 0.0
iYS854_wNdh_2b_NADH4_FADH2D_del.reactions.FADH2D.bounds = 0.0, 0.0

iYS854_wNdh_2b_NADPH4_del.reactions.NADPH4.bounds = 0.0, 0.0

iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del.reactions.NADH4.bounds = 0.0, 0.0
iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del.reactions.FADH2D.bounds = 0.0, 0.0
iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del.reactions.NADPH4.bounds = 0.0, 0.0

# %%
# Obtain FBA solutions 
iYS854_wNdh_2b_NADH4_del_sol = iYS854_wNdh_2b_NADH4_del.optimize()
iYS854_wNdh_2b_FADH2D_del_sol = iYS854_wNdh_2b_FADH2D_del.optimize()
iYS854_wNdh_2b_NADH4_FADH2D_del_sol = iYS854_wNdh_2b_NADH4_FADH2D_del.optimize()
iYS854_wNdh_2b_NADPH4_del_sol = iYS854_wNdh_2b_NADPH4_del.optimize()
iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del_sol = iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del.optimize()

iYS854_wNdh_2b_NADH4_del_fluxes = list(iYS854_wNdh_2b_NADH4_del_sol.fluxes)
iYS854_wNdh_2b_FADH2D_del_fluxes = list(iYS854_wNdh_2b_FADH2D_del_sol.fluxes)
iYS854_wNdh_2b_NADH4_FADH2D_del_fluxes = list(iYS854_wNdh_2b_NADH4_FADH2D_del_sol.fluxes)
iYS854_wNdh_2b_NADPH4_del_fluxes = list(iYS854_wNdh_2b_NADPH4_del_sol.fluxes)
iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del_fluxes = list(iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del_sol.fluxes)

# %%
# Create dataframe with flux distributions with and without mutations
iYS854allDels = pd.DataFrame({'id':iYS854_wNdh_2b_Reacts_id, 'name':iYS854_wNdh_2b_Reacts_name, 'stoichiometry':iYS854_wNdh_2b_Reacts_stoich, 'iYS854_original_fluxes':iYS854_Reacts_fluxes, 'iYS854_with_ndh_2b_fluxes':iYS854_wNdh_2b_Reacts_fluxes, 'iYS854_NADH4_del_fluxes':iYS854_NADH4_del_fluxes, 'iYS854_FADH2D_del_fluxes':iYS854_FADH2D_del_fluxes, 'iYS854_NADH4_FADH2D_del_fluxes':iYS854_NADH4_FADH2D_del_fluxes, 'iYS854_wNdh_2b_NADH4_del_fluxes':iYS854_wNdh_2b_NADH4_del_fluxes, 'iYS854_wNdh_2b_FADH2D_del_fluxes':iYS854_wNdh_2b_FADH2D_del_fluxes, 'iYS854_wNdh_2b_NADH4_FADH2D_del_fluxes':iYS854_wNdh_2b_NADH4_FADH2D_del_fluxes, 'iYS854_wNdh_2b_NADPH4_del_fluxes':iYS854_wNdh_2b_NADPH4_del_fluxes, 'iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del_fluxes':iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del_fluxes})

# %%
# Filter the dataframe to keep just fluxes that are altered between conditions
iYS854allDels_filt = iYS854allDels[iYS854allDels[['iYS854_original_fluxes', 'iYS854_with_ndh_2b_fluxes', 'iYS854_NADH4_del_fluxes', 'iYS854_FADH2D_del_fluxes', 'iYS854_NADH4_FADH2D_del_fluxes', 'iYS854_wNdh_2b_NADPH4_del_fluxes', 'iYS854_wNdh_2b_NADH4_FADH2D_NADPH4_del_fluxes']].nunique(axis = 1).gt(1)]
iYS854allDels_filt
# Out:
#                                   id  \
# 0                           10M3HDHL
# 1                          10M3OACPO
# 2                            10M3OUO
# 3                             10MDOD
# 4                            10MTDAO
# 5                            10MTU2A
# 6                             10MUAM
# 7                            11M3ODO
# 8                           11MDAMCA
# 9                            11MHDOD
# 10                          11MTRDOC
# 11                          12M3HTDH
# 12                          12M3HTHL
# 13                          12M3OXOT
# 14                           12M3TDA
# 15                          12MTACPM
# 16                           12MTT2E
# 17                           12TTACA
# 19                         3OAS120_2
# 20                        13M3HTDAHL
# 21                         13M3OTDAO
# 22                           13MTDAM
# 23                          13MTTDAO
# 24                          14M3HDEC
# ...

# %%
# Export csv file
iYS854allDels_filt.to_csv(path_or_buf='C:/Users/Guillem/Documents/PhD/comput/wrkng_dirs_clean/SAureus_simulations/iYS854allDels_filt.csv')

# %%
print('complete model: ', iSB619.optimize())
with iSB619:
    iSB619.reactions.NADH6.knock_out()
    print('NADH6 knocked out: ', iSB619.optimize())
    
# Impairment from 0.158 to 0.142
# Out:
# complete model:  <Solution 0.158 at 0x24d9ca89788>
# NADH6 knocked out:  <Solution 0.142 at 0x24d9ca891c8>

# %%
print('complete model: ', iSB619.optimize())
with iSB619:
    iSB619.reactions.NADH7.knock_out()
    print('NADH7 knocked out: ', iSB619.optimize())
    
# No effect
# Out:
# complete model:  <Solution 0.158 at 0x24d9ca85188>
# NADH7 knocked out:  <Solution 0.158 at 0x24d9ca85c88>

# %%
print('complete model: ', iSB619.optimize())
with iSB619:
    iSB619.reactions.NADH8.knock_out()
    print('NADH8 knocked out: ', iSB619.optimize())
    
# No effect
# Out:
# complete model:  <Solution 0.158 at 0x24d9ca88448>
# NADH8 knocked out:  <Solution 0.158 at 0x24d9ca77088>

# %%
print('complete model: ', iSB619.optimize())
with iSB619:
    iSB619.reactions.NADH9.knock_out()
    print('NADH9 knocked out: ', iSB619.optimize())
    
# No effect
# Out:
# complete model:  <Solution 0.158 at 0x24d9ca77c48>
# NADH9 knocked out:  <Solution 0.158 at 0x24d9ca77c08>

# %%
print('complete model: ', iSB619.optimize())
with iSB619:
    iSB619.reactions.NADH10.knock_out()
    print('NADH10 knocked out: ', iSB619.optimize())
    
# No effect
# Out:
# complete model:  <Solution 0.158 at 0x24d9ca89888>
# NADH10 knocked out:  <Solution 0.158 at 0x24d9ca89e88>

# %%
iYS854.reactions.NADH4
# Out:
# <Reaction NADH4 at 0x24d9e7fd448>

# %%
iYS854.reactions.FADH2D
# Out:
# <Reaction FADH2D at 0x24d9e514908>

# %%
# Knock out NADH + quinone --> NAD+ + quinol
print('complete model: ', iYS854.optimize())
with iYS854:
    iYS854.reactions.NADH4.knock_out()
    print('NADH4 knocked out: ', iYS854.optimize())
    
# No effect
# Out:
# complete model:  <Solution 1.360 at 0x24d9ca94f08>
# NADH4 knocked out:  <Solution 1.360 at 0x24d9ca9c088>

# %%
# Knock out FADH + quinone --> FAD+ + quinol
print('complete model: ', iYS854.optimize())
with iYS854:
    iYS854.reactions.FADH2D.knock_out()
    print('FADH2D knocked out: ', iYS854.optimize())
    
# Decreasses biomass flux from 1.360 to 1.269
# Out:
# complete model:  <Solution 1.360 at 0x24d9ca9c0c8>
# FADH2D knocked out:  <Solution 1.269 at 0x24d9ca9cac8>

# %% [markdown]
# Do copies of the models and delete all of the involved reactions to see how biomass flux is afected.

# %%
import copy

iSA863_nadQdel = cobra.io.read_sbml_model(join(data_dir, "Dataset_1.xml"))
iSB619_nadQdel = copy.deepcopy(iSB619)
iYS854_nadFadQdel = copy.deepcopy(iYS854)

# %%
iSA863_nadQdel.optimize()
# Out:
# <Solution 16.493 at 0x24d9a724688>

# %%
# Remove both reactions
iSA863_nadQdel.remove_reactions([getattr(iSA863_nadQdel.reactions, "NADH10"), getattr(iSA863_nadQdel.reactions, "NADH7")])

# %%
# When removed both biomass flux approximates 0
iSA863_nadQdel.optimize()
# Out:
# <Solution 16.493 at 0x24d9c389f88>

# %%
iSA863.optimize()
# Out:
# <Solution 16.493 at 0x2237e4785c8>

# %%
# Remove both reactions
iSB619_nadQdel.remove_reactions([getattr(iSB619_nadQdel.reactions, "NADH5"), getattr(iSB619_nadQdel.reactions, "NADH6"), getattr(iSB619_nadQdel.reactions, "NADH7"), getattr(iSB619_nadQdel.reactions, "NADH8"), getattr(iSB619_nadQdel.reactions, "NADH9"), getattr(iSB619_nadQdel.reactions, "NADH10")])

# %%
iSB619_nadQdel.optimize()
# Out:
# <Solution 0.142 at 0x2237db6eb48>

# %%
iSB619.optimize()
# Out:
# <Solution 0.158 at 0x2237e2a0b48>

# %%
# Remove both reactions
iYS854_nadFadQdel.remove_reactions([getattr(iYS854_nadFadQdel.reactions, "NADH4"), getattr(iYS854_nadFadQdel.reactions, "FADH2D")])

# %%
iYS854_nadFadQdel.optimize()
# Out:
# <Solution 1.269 at 0x2b03b78b548>

# %%
iYS854.optimize()

# %%
iSA863.metabolites.get_by_id("nadh_c")
# Out:
# <Metabolite nadh_c at 0x1b7ab5075c8>

# %%
iSA863.metabolites.get_by_id("nadph_c")
# Out:
# <Metabolite nadph_c at 0x1b7ab507748>

# %%
print('complete model: ', iSA863.optimize())
with iSA863:
    iSA863.genes.SAUSA300_0844.knock_out()
    print('SAUSA300_0425 knocked out: ', iSA863.optimize())
# Out:
# complete model:  <Solution 16.493 at 0x1b7ae7899c8>
# SAUSA300_0425 knocked out:  <Solution 16.493 at 0x1b7ae7959c8>
